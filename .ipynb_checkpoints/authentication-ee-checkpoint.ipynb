# %%
import sys
import ee

# %% [markdown]
# ###### Use %%bash instead of %%cmd if on Linux

# %%
# %%cmd
# earthengine authenticate --quiet

# %% [markdown]
# ###### Click on the link generated by the cell above and avail your authentication token

# %% [markdown]
# ###### Paste the authentication token in the next cell

# %%
# %%cmd
# earthengine authenticate --authorization-code=YOUR_AUTH_KEY_HERE

# %%
try:
  ee.Initialize()
  print('EE Initialized Successfully')
except ee.EEException as e:
  print('Failed to initialize')
except:
    print("Unexpected Error:", sys.exc_info()[0])
    raise

# %%
dir(ee)
